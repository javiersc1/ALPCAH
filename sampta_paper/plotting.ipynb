# %% [markdown]
# # Libraries

# %%
using Plots
using Random
using Distributions
using LinearAlgebra
include("pogm_restart.jl")
using ProgressMeter
using HePPCAT
using Distributed
using JLD

# %% [markdown]
# # Known Variance Data Import

# %%
varianceRatio = range( 1, 100,20) #20 for plot
pointRatio = range(1,100,20); # 20 points for plot

# %%
tickVector = vcat(1:9:100);

# %%
knownVarianceHPCA = load("knownVarianceMatrix.jld", "hpcaMatrix");

# %%
knownVariancePPCA = load("knownVarianceMatrix.jld", "ppcaMatrix");

# %%
knownVariancePPCA_GOOD = load("knownVarianceMatrix.jld", "goodsubspaceMatrix");

# %% [markdown]
# # KNOWN VARIANCE PLOTS

# %%
heatmap(pointRatio, varianceRatio, knownVarianceHPCA./knownVariancePPCA, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
# title HPCA/PCA [KNOWN VAR]
#savefig("ALPCAH_KNOWN_PCA_HEATMAP.pdf")

# %%
heatmap(pointRatio, varianceRatio, knownVarianceHPCA./knownVariancePPCA_GOOD, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true,xticks=tickVector, yticks = tickVector)
# HPCA/PCA-GOOD [KNOWN VAR]
#savefig("ALPCAH_KNOWN_PCA_GOOD_HEATMAP.pdf")

# %%
#heatmap(pointRatio, varianceRatio, knownVarianceHPCA, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
# HPCA [KNOWN VAR]
#savefig("UNKNOWN_HEPPCAT.pdf")

# %%
#heatmap(pointRatio, varianceRatio, knownVariancePPCA, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
# PPCA [KNOWN VAR]
#savefig("UNKNOWN_HEPPCAT.pdf")

# %% [markdown]
# # Unknown Variance Data Import RPCA

# %%
unknownVarianceHPCA = load("unknownVarianceMatrixRPCA.jld", "hpcaMatrix");
unknownVariancePPCA = load("unknownVarianceMatrixRPCA.jld", "ppcaMatrix");
unknownVarianceRPCA = load("unknownVarianceMatrixRPCA.jld", "rpcaMatrix");

# %% [markdown]
# # RPCA PLOTS

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHPCA./unknownVarianceRPCA, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
# HPCA/RPCA [UNKNOWN VAR, NO GROUPS]
#savefig("ALPCAH_UNKNOWN_RPCA_HEATMAP.pdf")

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHPCA, title="HPCA [UNKNOWN VAR, NO GROUPS]", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceRPCA, title="RPCA [UNKNOWN VAR, NO GROUPS]", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)

# %% [markdown]
# # Unknown Variance Data Import HEPPCAT

# %%
unknownVarianceHPCA2 = load("unknownVarianceMatrixRPCA.jld", "hpcaMatrix");
unknownVariancePPCA2 = load("unknownVarianceMatrix.jld", "ppcaMatrix");
unknownVarianceHEPPCAT = load("unknownVarianceMatrix.jld", "heppcatMatrix");

# %% [markdown]
# # HEPPCAT PLOTS

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHPCA2./unknownVarianceHEPPCAT, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
# HPCA/HEPPCAT [UNKNOWN VAR, NO GROUPS]
#savefig("ALPCAH_UNKNOWN_HEPPCAT_HEATMAP.pdf")

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHPCA2./unknownVariancePPCA2, title="HPCA/PPCA [UNKNOWN VAR, NO GROUPS]", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
#savefig("HPCA_UNKNOWN_PPCA_HEATMAP.pdf")

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHPCA2, title="HPCA [UNKNOWN VAR, NO GROUPS]", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
#savefig("UNKNOWN_HPCA.pdf")

# %%
heatmap(pointRatio, varianceRatio, unknownVarianceHEPPCAT, title="HEPPCAT [UNKNOWN VAR, NO GROUPS]", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector)
#savefig("UNKNOWN_HEPPCAT.pdf")

# %%
cvHPCA = load("crossValidationHPCA.jld", "lambdaMatrix");

# %%
heatmap(pointRatio, varianceRatio, cvHPCA, title="", xlabel="Point Ratio N2/N1, N1=10", ylabel="Variance Ratio ν2/ν1, ν1=1",yflip=true, xticks=tickVector, yticks = tickVector,c=:viridis)
#HPCA CROSS VALIDATION MATRIX
#savefig("ALPCAH_CV_MATRIX.pdf")
