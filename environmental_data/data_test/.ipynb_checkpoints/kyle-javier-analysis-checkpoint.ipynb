# %%
using LinearAlgebra
using CSV
using DataFrames
using Statistics
using JLD

# %%
dataDir = pwd()*"/script"
# Out:
# "/home/javier/Desktop/alpcah/environmental_data/data_test/script"

# %%
purple_air_sensors = 725
purpleSet = []
valid_purpleair = []
for i = 1:purple_air_sensors
    push!(purpleSet, Matrix(CSV.read(dataDir*"/data_purpleair_case1_"*string(i)*".csv", DataFrame))[:,1:2:3])
    if size(purpleSet[i])[1]==119
        push!(valid_purpleair, i)
    end
end

# %%
length(valid_purpleair)
# Out:
# 339

# %%
#airMatrix = Matrix(CSV.read(dataDir*"/data_airnow_case1.csv", DataFrame))

# %%
#airSensors = unique(airMatrix[:,3])

# %%
# airSet = []
# count = 1
# valid_airnow = []
# for i in airSensors
#     push!(airSet, airMatrix[airMatrix[:,3] .== i,:] )
#     if size(airSet[count])[1] >= 119
#         push!(valid_airnow,count)
#     end
#     count = count + 1
# end

# %%
#valid_airnow

# %%
sum([1 2 2 4 5] .== 2)
# Out:
# 2

# %%
purpleMatrix = zeros(119, length(valid_purpleair))
count = 1
index = []
for i in valid_purpleair
    if sum(purpleSet[i][:,2] .> 500) == 0
        purpleMatrix[:,count] = purpleSet[i][:,2]
        push!(index,count)
        count = count + 1
    end
end
purpleMatrix = purpleMatrix[:,index];

# %%
using Plots
heatmap(purpleMatrix)

# %%
# airMatrix = zeros(119, length(valid_airnow))
# count = 1
# for i in valid_airnow
#     airMatrix[:,count] = coalesce.(airSet[i][:,4], 0)[1:119]
#     count = count + 1
# end

# %%
# airLabels = 1*ones(Int,size(airMatrix)[2]);
# purpleLabels = 1*ones(Int,size(purpleMatrix)[2]);

# %%
using PyCall
@pyimport pickle

function mypickle(filename, obj)
    out = open(filename,"w")
    pickle.dump(obj, out)
    close(out)
 end

function myunpickle(filename)
    r = nothing
    @pywith pybuiltin("open")(filename,"rb") as f begin
        r = pickle.load(f)
    end
    return r
end
# Out:
# myunpickle (generic function with 1 method)

# %%
data = myunpickle("../airData.pickle")[2];
# data[1] .= max.(data[1],0)
# data[2] .= max.(data[2],0)
# # data[2] .= min.(data[2],250) ### cap maximum reading
# data[1] .-= mean(data[1],dims=2)
# data[2] .-= mean(data[2],dims=2);

# %%
using JLD
airMatrix = Float64.(load("script2/airMatrix.jld", "airMatrix"))[1:119,:]
# Out:
# 119×55 Matrix{Float64}:
#   7.7  9.4  11.3  10.3  13.1  10.8  …  4.6  20.2   2.6  31.6  38.7   2.6
#   6.2  7.7  12.1  10.3  11.5   9.4     3.8  24.0   3.8  29.2  41.2   4.3
#   5.5  5.8  11.0  10.1  10.3   8.6     2.9  25.9   2.9  29.2  44.4   4.6
#   6.2  7.4  10.1  10.6  10.6   9.8     2.4  28.3   1.9  31.6  47.7   3.4
#   9.1  8.6  10.6  10.8  12.1   9.4     2.6  35.5   2.4  33.0  48.9   2.2
#  10.1  8.4  11.0  10.3  12.1  11.3  …  2.9  42.0   4.8  34.0  54.6   1.4
#  10.1  7.7   9.6   9.1  12.0  12.6     2.4  42.0   4.3  32.1  55.0   8.6
#  10.1  8.9   9.8  10.1  13.1  12.1     4.3  39.2   3.6  32.1  53.0  13.5
#   9.1  8.4   9.4   8.9  12.0  11.5     4.6  35.5   4.8  31.6  50.9   9.1
#   7.9  6.2   9.4   6.2   9.6   9.4     3.4  34.0   5.5  30.2  50.1  14.5
#   7.4  6.0   9.1   5.5   8.6  10.6  …  1.7  32.1   4.8  29.7  51.3  14.0
#   6.7  7.4   8.2   5.3   7.9   9.8     1.2  34.4   3.4  29.2  47.7  13.1
#   4.8  7.2   7.7   6.0   9.4   9.4     2.2  35.5   3.6  31.6  47.7  11.5
#   ⋮                            ⋮    ⋱        ⋮
#   1.0  2.6   2.4   1.9   2.9   5.0     2.6   6.0   1.9  13.1   9.6   7.7
#   0.5  2.9   1.7   1.9   2.4   4.6     2.4   5.8   1.0  11.5   8.4   4.3
#   0.2  2.9   1.9   1.9   2.6   4.8     1.2   7.2   0.5   9.6   9.6   1.2
#   1.3  3.4   1.9   2.4   5.3   5.8  …  1.4   8.9   0.2   9.4  12.1   1.9
#   2.4  3.1   1.4   2.2   4.6   5.5     2.2   6.5   2.2   8.6  11.5   3.1
#   7.2  1.7   2.6   2.6   4.8   5.3     2.2   1.9   2.4   7.9  10.3   2.4
#   8.2  1.9   4.3   3.8   6.5   5.0     1.9   3.6   2.2   7.4   7.7   2.2
#   6.0  2.9   4.1   4.3   5.8   6.5     1.4   2.9   3.1   5.8   5.8   1.7
#   3.6  2.4   4.6   4.3   4.8   6.2  …  0.7   1.55  3.1   4.3   4.3   1.2
#   3.6  2.2   5.8   6.7   3.8   6.7     0.6   0.2   2.4   3.1   4.3   1.2
#   3.8  2.6   7.9   6.7   4.8   8.4     0.5   1.4   1.7   1.9   6.0   0.5
#   3.4  4.3   7.4   7.9   7.9   8.2     1.7   2.6   0.7   2.4   7.4   1.2

# %%
using Plots
using Random
plot(mean(airMatrix, dims=2), label="airnow mean")
plot!(mean(purpleMatrix2, dims=2), label="purpleair mean")
plot!(title="California Data - Mine", xlabel="Time (~1week)", ylabel="PM2.5 Concenctration")

# %%
using NearestNeighbors
kdtree = KDTree(airMatrix)
knn(kdtree, mean(airMatrix, dims=2), 25, true)[1][1]
#plot( mean(airMatrix[:,idxs[1]], dims=2) )
# Out:
# 25-element Vector{Int64}:
#  33
#  34
#  41
#  16
#  28
#  21
#  12
#  31
#  27
#   5
#  14
#  18
#  20
#  22
#   6
#   9
#  30
#  29
#  19
#  17
#   8
#   2
#  37
#  32
#  13

# %%
kdtree = KDTree(purpleMatrix)
purpleMatrix2 = []
for i=1:size(airMatrix)[2]
    idxs = knn(kdtree, airMatrix[:,i], 20, true)[1]
    push!(purpleMatrix2, purpleMatrix[:,idxs])
end
purpleMatrix2 = reduce(hcat,purpleMatrix2)
purpleMatrix2 = reduce(hcat, unique(eachcol(purpleMatrix2)))
# Out:
# 119×113 Matrix{Float64}:
#  3.333    3.7165  2.403   6.483   4.982   …   4.8665  2.966   2.1805  3.796
#  5.713   10.9675  2.456   5.0405  4.245       9.6545  3.201   1.6485  3.6585
#  3.1155   7.8435  3.337   5.662   4.7695     16.0675  7.9375  2.7845  3.5
#  5.4975   5.9725  3.672   5.46    5.003       5.6045  4.8405  2.5265  3.424
#  5.058   12.2165  6.0395  2.6745  4.3855      9.9555  4.457   3.827   3.4155
#  5.0605   3.6     3.2915  4.149   3.224   …   7.372   2.574   4.0355  4.6425
#  3.535    7.88    4.681   7.0505  4.766       9.785   4.346   5.3715  6.901
#  3.898    4.725   4.4765  1.53    4.9925      5.1445  1.9005  2.742   5.0295
#  8.0805   5.7355  3.3545  4.567   3.3675      6.6765  7.7995  5.912   2.9625
#  4.911    3.679   2.28    7.871   5.11        5.054   7.6495  3.5375  5.63
#  4.7195   5.0025  0.892   1.486   4.3455  …   6.823   4.0065  3.5215  1.305
#  7.574    5.8765  2.9725  3.1335  2.8015     16.122   7.56    4.4485  2.9945
#  4.746    5.731   4.4805  5.1095  3.2845      4.4205  5.7685  2.88    4.7885
#  ⋮                                        ⋱           ⋮
#  2.5945   1.5675  0.447   0.6485  2.585       4.0535  6.487   4.6455  5.069
#  2.6685   4.968   1.081   2.488   2.1875      2.3515  9.1425  5.569   1.8715
#  1.804    2.5215  0.672   2.2905  4.272       1.405   7.0415  4.1105  1.7395
#  2.0265   1.089   0.638   2.782   2.2615  …   2.3075  5.1045  4.304   3.5085
#  2.074    6.6115  1.3405  3.4735  5.266       0.0465  5.0355  4.235   5.123
#  5.6465   2.2795  0.2365  6.8475  5.2145      2.9935  5.032   6.7195  3.776
#  2.488    3.9575  0.1735  5.287   3.668       2.4925  8.822   5.4275  3.9235
#  0.734    3.237   0.956   2.496   0.815       2.5515  7.545   4.507   2.561
#  6.773    3.7225  0.9085  1.5     2.269   …   3.12    3.0375  5.0025  4.499
#  4.987    3.742   2.5905  2.687   3.674       1.019   8.522   3.2415  2.8715
#  4.6245   1.86    0.019   1.031   4.07        1.0635  8.099   3.7935  3.8075
#  6.4155   3.274   0.012   1.651   2.0005      2.5885  7.599   3.823   3.1995

# %%
scatter(svdvals(hcat(airMatrix,purpleMatrix2))[1:50])

# %%
include("/home/javier/Desktop/alpcah/alpcahFamily.jl")
U = LR_ALPCAH_GROUPED(hcat(airMatrix,purpleMatrix2),30; alpcahIter= 1000, goodpts=55)
v = groupedVarianceUpdate(hcat(airMatrix,purpleMatrix2), U*U'*hcat(airMatrix,purpleMatrix2), 55)
scatter(v[56:end])
scatter!(v[1:55])

# %%
using Plots
plot(mean(data[1], dims=2), label="airnow mean")
plot!(mean(data[2], dims=2), label="purpleair mean")
plot!(title="California Data - Kyle", xlabel="Time (~1week)", ylabel="PM2.5 Concenctration")

# %%
scatter(svdvals(hcat(data[1],data[2]))[1:50])

# %%
U = LR_ALPCAH_GROUPED(hcat(data[1],data[2]),30; alpcahIter= 1000, goodpts=46)
v = groupedVarianceUpdate(hcat(data[1],data[2]), U*U'*hcat(data[1],data[2]), 46)
scatter(v[47:end])
scatter!(v[1:46])

# %%
plot(data[1][:,1:25])

# %%
plot(airMatrix[:,1:25])
